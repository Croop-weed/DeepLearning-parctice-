# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
X,y = make_classification(n_samples=100, n_features=2,
                          n_informative=1,n_redundant=0,
                          n_classes=2,random_state=41,
                          n_clusters_per_class = 1,hypercube=False,class_sep=15)

# %%
import matplotlib.pyplot as plt
plt.scatter(X[:,0],X[:,1],c=y)

# %%
def perceptron(X,y):
    #adding bias
    x = np.insert(X,0,1,axis=1)
    w = np.ones(x.shape[1])
    lr = 0.01
    
    for i in range(1000):
        #selecting random data point
        j = np.random.randint(0,100)
        #prediction
        y_hat = step(np.dot(w,x[j]))
        #weight update
        weight_update = lr * (y[j] - y_hat) * x[j]
        w += weight_update
    
    return w[0],w[1:]

# %%
def precptron_with_lf(X,y):
    w1=w2=b= 1
    lr = 0.01
    
    for i in range(1000):
        for j in range(X.shape[0]):
            z = w1*X[j][0] + w2*X[j][1] + b
        if z*y[j] <= 0:
            w1 += lr * y[j] * X[j][0]
            w2 += lr * y[j] * X[j][1]
            b += lr * y[j]
    return w1,w2,b

# %%
def step(x):
    return 1 if x>=0 else 0

# %%
intercept,weights = perceptron(X,y)
print(intercept,weights)
# Out:
# 1.11 [1.12249992 0.49515998]

# %%
w1,w2,b = precptron_with_lf(X,y)

# %%
m = -weights[0]/weights[1]
c = -intercept/weights[1]

# %%
x_input = np.linspace(-3,3,100)
y_input = m*x_input + c

# %%
plt.plot(x_input,y_input,color='red',linewidth=2)
plt.scatter(X[:,0],X[:,1],c=y,cmap='winter',s=100)
plt.ylim(-3,2)
# Out:
# (-3.0, 2.0)

# %%
m = -w1/w2
c = -b/w2
x_input = np.linspace(-3,3,100)
y_input = m * x_input + c

# %%
plt.plot(x_input,y_input,color='red',linewidth=2)    
plt.scatter(X[:,0],X[:,1],c=y,cmap='winter',s=100)
plt.ylim(-3,2)
# Out:
# (-3.0, 2.0)
